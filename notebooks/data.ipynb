# %%
import pandas as pd

# %%
df = pd.read_csv('final_2000_2020_with_odds.csv')
df
# Out:
#             Date Div     HomeTeam       AwayTeam  FTHG  FTAG  HTHG  HTAG FTR  \
# 0     2000-08-19  E0     Charlton       Man City     4     0     2     0   H
# 1     2000-08-19  E0      Chelsea       West Ham     4     2     1     0   H
# 2     2000-08-19  E0     Coventry  Middlesbrough     1     3     1     1   A
# 3     2000-08-19  E0        Derby    Southampton     2     2     1     2   D
# 4     2000-08-19  E0        Leeds        Everton     2     0     2     0   H
# ...          ...  ..          ...            ...   ...   ...   ...   ...  ..
# 7255  2020-02-15  E0      Norwich      Liverpool     0     1     0     0   A
# 7256  2020-02-16  E0  Aston Villa      Tottenham     2     3     1     2   A
# 7257  2020-02-16  E0      Arsenal      Newcastle     4     0     0     0   H
# 7258  2020-02-17  E0      Chelsea     Man United     0     2     0     1   A
# 7259  2020-02-19  E0     Man City       West Ham     2     0     1     0   H
#
# ...
